# %% [markdown]
# # Fetch OSM — Réseau vélo & marche
#
# Exécuter les cellules dans l'ordre.

# %%
# Réseau vélo (cycleway + primary/secondary + arrêts de bus)
# %run fetch_bike_simplified.py

# %%
# Réseau piéton (prioritaire + secondaire + plateformes)
# %run fetch_walk_simplified.py

# %%
# Plateformes TP
# %run fetch_platform_simplified.py
