# %% [markdown]
# # Load OSM Bike And Walk Networks
#
# Notebook minimal pour lancer `load_osm_networks_bike_walk.py`.

# %%
from pathlib import Path
import runpy

script = Path("load_osm_networks_bike_walk.py")
assert script.exists(), script
print(f"Script: {script}")

# %%
_ = runpy.run_path(str(script), run_name="__main__")
