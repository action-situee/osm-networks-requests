# %% [markdown]
# # Load OSM Parking Spots
#
# Notebook minimal pour lancer `load_osm_parking_spots.py`.

# %%
from pathlib import Path
import runpy

script = Path("load_osm_parking_spots.py")
assert script.exists(), script
print(f"Script: {script}")

# %%
_ = runpy.run_path(str(script), run_name="__main__")
